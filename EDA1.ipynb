# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
data = pd.read_csv('Cardiotocographic.csv')
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
# 1. Handling Missing Values
# Checking missing values
missing_values = data.isnull().sum()
missing_values
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
# Impute missing values with the mean
data_filled = data.fillna(data.mean())
data_filled
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
# 2. Removing Invalid Class Values
data_cleaned = data_filled[data_filled['NSP'].isin([1, 2, 3])]
data_cleaned
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2120  140.000000  0.000000  0.000000  0.004975  0.001244  0.0  0.0  77.0
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency  NSP
# ...

# %%
# 3. Removing Outliers using Z-score
from scipy.stats import zscore
z_scores = np.abs(zscore(data_cleaned))
z_scores
# Out:
#             LB        AC         FM        UC        DL        DS        DP  \
# 0     1.183253  0.746239   0.151872  1.300103  0.576021  0.014393  0.214571
# 1     0.116442  0.729146   0.151872  0.592319  0.398286  0.014393  0.214571
# 2     0.027541  0.022089   0.151872  1.163661  0.438747  0.014393  0.214571
# 3     0.061360  0.154007   0.151872  0.996426  0.206168  0.014393  0.214571
# 4     0.121044  0.760384   0.151872  1.115509  0.576021  0.014393  0.214571
# ...        ...       ...        ...       ...       ...       ...       ...
# 2120  0.594766  0.746239   0.151872  0.175704  0.196114  0.014393  0.214571
# 2121  0.594766  0.746239  13.909641  0.902648  0.576021  0.014393  0.214571
# 2122  0.594766  0.567101   0.151872  0.770200  0.576021  0.014393  0.214571
# 2124  0.594766  0.589235   0.151872  0.512344  0.576021  0.014393  0.214571
# 2125  0.772567  0.372625   0.154616  1.095997  0.576021  0.014393  0.214571
#
# ...

# %%
data_no_outliers = data_cleaned[(z_scores < 3).all(axis=1)]
data_no_outliers
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2119  140.000000  0.000000  0.000000  0.006764  0.001127  0.0  0.0  79.0
# 2120  140.000000  0.000000  0.000000  0.004975  0.001244  0.0  0.0  77.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency  NSP
# ...

# %%
# 4. Statistical Summary
summary_statistics = data_no_outliers.describe()
summary_statistics
# Out:
#                 LB           AC           FM           UC           DL  \
# count  1761.000000  1761.000000  1761.000000  1761.000000  1761.000000
# mean    133.319028     0.003207     0.004304     0.004368     0.001720
# std      10.011007     0.003793     0.013765     0.002903     0.002686
# min     106.000000    -0.000185    -0.005106    -0.000132    -0.000124
# 25%     126.000000     0.000000     0.000000     0.001929     0.000000
# 50%     133.000000     0.001718     0.000000     0.004532     0.000000
# 75%     141.000000     0.005720     0.002339     0.006579     0.003035
# max     160.000000     0.016000     0.189320     0.012072     0.011658
#
#                  DS           DP         ASTV         MSTV         ALTV  \
# count  1.761000e+03  1761.000000  1761.000000  1761.000000  1761.000000
# mean   1.026528e-08     0.000097    46.727725     1.282371     9.349100
# std    6.003008e-07     0.000398    16.872589     0.786260    16.814137
# ...

# %%
# 5. Visualizations
plt.figure(figsize=(10, 6))
sns.heatmap(data_no_outliers.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Histogram of the target variable NSP
plt.figure(figsize=(6, 4))
sns.countplot(x='NSP', data=data_no_outliers)
plt.title("Class Distribution")
plt.show()

# %%
# Box plot to check for outliers
plt.figure(figsize=(10, 6))
sns.boxplot(data=data_no_outliers, orient="h")
plt.title("Box Plot for Outlier Detection")
plt.show()

# %%
# 6. Checking for class imbalance
class_distribution = data_no_outliers['NSP'].value_counts()
class_distribution
# Out:
# NSP
# 1.0    1415
# 2.0     261
# 3.0      85
# Name: count, dtype: int64

# %%
summary_statistics, class_distribution
# Out:
# (                LB           AC           FM           UC           DL  \
#  count  1761.000000  1761.000000  1761.000000  1761.000000  1761.000000
#  mean    133.319028     0.003207     0.004304     0.004368     0.001720
#  std      10.011007     0.003793     0.013765     0.002903     0.002686
#  min     106.000000    -0.000185    -0.005106    -0.000132    -0.000124
#  25%     126.000000     0.000000     0.000000     0.001929     0.000000
#  50%     133.000000     0.001718     0.000000     0.004532     0.000000
#  75%     141.000000     0.005720     0.002339     0.006579     0.003035
#  max     160.000000     0.016000     0.189320     0.012072     0.011658
#
#                   DS           DP         ASTV         MSTV         ALTV  \
#  count  1.761000e+03  1761.000000  1761.000000  1761.000000  1761.000000
#  mean   1.026528e-08     0.000097    46.727725     1.282371     9.349100
#  std    6.003008e-07     0.000398    16.872589     0.786260    16.814137
# ...
